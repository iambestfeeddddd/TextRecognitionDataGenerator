# %%
# !git clone https://github.com/iambestfeeddddd/TextRecognitionDataGenerator.git
# Out:
# Cloning into 'TextRecognitionDataGenerator'...
# remote: Enumerating objects: 1678, done.
# remote: Counting objects: 100% (150/150), done.
# remote: Compressing objects: 100% (98/98), done.
# remote: Total 1678 (delta 52), reused 140 (delta 49), pack-reused 1528
# Receiving objects: 100% (1678/1678), 179.56 MiB | 22.10 MiB/s, done.
# Resolving deltas: 100% (657/657), done.
# Updating files: 100% (596/596), done.

# %%
# %cd TextRecognitionDataGenerator
# Out:
# /kaggle/working/TextRecognitionDataGenerator

# %%
# !pip install -q -r requirements.txt
# Out:
# WARNING: The candidate selected for download or install is a yanked version: 'arabic-reshaper' candidate (version 2.1.3 at https://files.pythonhosted.org/packages/47/27/7b9b824f5342d8ee180027333f2e15842ea36f5bc2d3d24a4e6bb31fb596/arabic_reshaper-2.1.3-py3-none-any.whl (from https://pypi.org/simple/arabic-reshaper/))
# Reason for being yanked: Doesn't work with Python 2

# %%
# %cd /kaggle/working/TextRecognitionDataGenerator/trdg
# Out:
# /kaggle/working/TextRecognitionDataGenerator/trdg

# %%
with open('/kaggle/input/gen-ocr-data-sources/gen_data_0.txt', 'r', encoding = 'utf-8') as fin:
    all_str = fin.read()

# %%
with open('/kaggle/working/TextRecognitionDataGenerator/trdg/texts/gen_data.txt', 'w', encoding = 'utf-8') as fout:
    fout.write(all_str)

# %%
# !python3 run.py -c 400000 -l vi  -w 5 -b 1 -na 2 -i texts/gen_data.txt
# Out:
# /opt/conda/lib/python3.10/site-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.23.5
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"
# /opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/__init__.py:98: UserWarning: unable to load libtensorflow_io_plugins.so: unable to open file: libtensorflow_io_plugins.so, from paths: ['/opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/libtensorflow_io_plugins.so']
# caused by: ['/opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/libtensorflow_io_plugins.so: undefined symbol: _ZN3tsl6StatusC1EN10tensorflow5error4CodeESt17basic_string_viewIcSt11char_traitsIcEENS_14SourceLocationE']
#   warnings.warn(f"unable to load libtensorflow_io_plugins.so: {e}")
# ...

# %%
# !zip -r -j /kaggle/working/output.zip /kaggle/working/TextRecognitionDataGenerator/trdg/out
# Out:
#   adding: 4.jpg (deflated 11%)
#   adding: 9.jpg (deflated 5%)
#   adding: 1.jpg (deflated 9%)
#   adding: 5.jpg (deflated 4%)
#   adding: labels.txt (deflated 19%)
#   adding: 0.jpg (deflated 6%)
#   adding: 2.jpg (deflated 4%)
#   adding: 7.jpg (deflated 6%)
#   adding: 8.jpg (deflated 9%)
#   adding: 6.jpg (deflated 6%)
#   adding: 3.jpg (deflated 5%)
